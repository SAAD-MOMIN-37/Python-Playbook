# %% [markdown]
# # 🐍 Student Management System
#
# ## Practical Implementation Notebook
#
# **Repository:** `python-playbook`
#
# **Notebook:** `03_student_management_system.ipynb`
#
# **Difficulty:** Intermediate
#
# ### Concepts Covered
# - Functions
# - Lists & Dictionaries
# - CRUD Operations
# - JSON File Handling
# - Menu-Driven Programming

# %% [markdown]
# ## Objective
# Build a menu-driven Student Management System using Python with CRUD operations and JSON persistence.

# %%
students = [
    {
        "roll_no": 101,
        "name": "Saad",
        "age": 21,
        "course": "AI",
        "marks": 95
    },
    {
        "roll_no": 102,
        "name": "Ali",
        "age": 20,
        "course": "ML",
        "marks": 88
    },
    {
        "roll_no": 103,
        "name": "Ahmed",
        "age": 22,
        "course": "Data Science",
        "marks": 91
    }
]

# %%
students
# Out:
# [{'roll_no': 101, 'name': 'Saad', 'age': 21, 'course': 'AI', 'marks': 95},
#  {'roll_no': 102, 'name': 'Ali', 'age': 20, 'course': 'ML', 'marks': 88},
#  {'roll_no': 103,
#   'name': 'Ahmed',
#   'age': 22,
#   'course': 'Data Science',
#   'marks': 91}]

# %%
def add_students():
    roll_no = int(input("Enter roll number :"))
    name = input("Enter name :")
    age = int(input("Enter age :"))
    course = input("Enter course :")
    marks = int(input("Enter marks :"))
    student = {
            "roll_no": roll_no,
            "name": name,
            "age": age,
            "course": course,
            "marks": marks
        }
    for existing_student in students:
        if existing_student  == existing_student["roll_no"]:
            print(f"Student with Roll No {roll_no} already exists.")
            return
        
    students.append(student)
    ptint("-"*70)
    print("✅Student added Successfully!!")
add_students()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 22
#      18
#      19     students.append(student)
#      20     ptint("-"*70)
#      21     print("✅Student added Successfully!!")
# ---> 22 add_students()
#
# Cell In[4], line 2, in add_students()
#       1 def add_students():
# ----> 2     roll_no = int(input("Enter roll number :"))
#       3     name = input("Enter name :")
#       4     age = int(input("Enter age :"))
#       5     course = input("Enter course :")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def display_students():
    if not students:
        print("No students Found!!")
        return
    for student in students:
        print("-"*70)
        print(f'Roll No : {student["roll_no"]}')
        print(f'Name    : {student["name"]}')
        print(f'Age     : {student["age"]}')
        print(f'Course  : {student["course"]}')
        print(f'Marks   : {student["marks"]}')
        print("-"*70)
display_students()
# Out:
# ----------------------------------------------------------------------
# Roll No : 101
# Name    : Saad
# Age     : 21
# Course  : AI
# Marks   : 95
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Roll No : 102
# Name    : Ali
# Age     : 20
# Course  : ML
# Marks   : 88
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Roll No : 103
# Name    : Ahmed
# Age     : 22
# Course  : Data Science
# Marks   : 91
# ----------------------------------------------------------------------

# %%
def search_students():
    rollno = int(input("Enter Roll No"))
    if not students:
        print("No students Found!!")
        return
    
    for student in students:
        if rollno == student["roll_no"]:
            print("-"*70)
            print(f'Roll No : {student["roll_no"]}')
            print(f'Name    : {student["name"]}')
            print(f'Age     : {student["age"]}')
            print(f'Course  : {student["course"]}')
            print(f'Marks   : {student["marks"]}')
            print("-"*70)
    
            return
            
    print("-"*70)
    print("Student Not Found!!")
    print("-"*70)
    return

search_students()

# %%
def update_students():
    rollno = int(input("Enter Roll No"))
    if not students:
        print("No students Found!!")
        return
    
    for student in students:
        if rollno == student["roll_no"]:
            print("-"*70)
            print(f"Before update")
            print("-"*70)
            print(f'Roll No : {student["roll_no"]}')
            print(f'Name    : {student["name"]}')
            print(f'Age     : {student["age"]}')
            print(f'Course  : {student["course"]}')
            print(f'Marks   : {student["marks"]}')
            print("-"*70)

            student["name"] = input("Enter new name :")
            student["age"] = int(input("Enter new age :"))
            student["course"] = input("Enter new course :")
            student["marks"] = int(input("Enter new marks :"))
            
            print("-"*70)
            print(f"After update")
            print("-"*70)
            print(f'Roll No : {student["roll_no"]}')
            print(f'Name    : {student["name"]}')
            print(f'Age     : {student["age"]}')
            print(f'Course  : {student["course"]}')
            print(f'Marks   : {student["marks"]}')
            print("-"*70)
    
            return
            
    print("-"*70)
    print("Student Not Found!!")
    print("-"*70)
    return

update_students()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 41
#      37     print("Student Not Found!!")
#      38     print("-"*70)
#      39     return
#      40
# ---> 41 update_students()
#
# Cell In[7], line 2, in update_students()
#       1 def update_students():
# ----> 2     rollno = int(input("Enter Roll No"))
#       3     if not students:
#       4         print("No students Found!!")
#       5         return
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def delete_students():
    rollno = int(input("Enter Roll No"))
    if not students:
        print("No students Found!!")
        return
    
    for student in students:
        if rollno == student["roll_no"]:
            print("-"*70)
            print(f"Student Information to delete")
            print("-"*70)
            print(f'Roll No : {student["roll_no"]}')
            print(f'Name    : {student["name"]}')
            print(f'Age     : {student["age"]}')
            print(f'Course  : {student["course"]}')
            print(f'Marks   : {student["marks"]}')
            print("-"*70)

            students.remove(student)
            print("Student Deleted!!")
            return
            
    print("-"*70)
    print("Student Not Found!!")
    print("-"*70)
    return

delete_students()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 28
#      24     print("Student Not Found!!")
#      25     print("-"*70)
#      26     return
#      27
# ---> 28 delete_students()
#
# Cell In[8], line 2, in delete_students()
#       1 def delete_students():
# ----> 2     rollno = int(input("Enter Roll No"))
#       3     if not students:
#       4         print("No students Found!!")
#       5         return
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import json
def save_students(file = "students.json"):
    with open(file, "w") as f:
        json.dump(students,f,indent =4)
    print("✅ Students saved successfully!")
save_students()
# Out:
# ✅ Students saved successfully!

# %%
import json

def load_students(file="students.json"):
    global students

    with open(file, "r") as f:
        students = json.load(f)

    print("✅ Students loaded successfully!")

# %%
students
# Out:
# [{'roll_no': 101, 'name': 'Saad', 'age': 21, 'course': 'AI', 'marks': 95},
#  {'roll_no': 102, 'name': 'Ali', 'age': 20, 'course': 'ML', 'marks': 88},
#  {'roll_no': 103,
#   'name': 'Ahmed',
#   'age': 22,
#   'course': 'Data Science',
#   'marks': 91},
#  {'roll_no': 104,
#   'name': 'Zuhayr',
#   'age': 5,
#   'course': 'COCOMELON',
#   'marks': 100}]

# %%
def system():
    # Loading JSON
    load_students()
    
    while True:
        print("="*70)
        print("STUDENT MANAGEMENT SYSTEM")
        print("="*70)
        print("\n1. Add Student")
        print("2. Display Students")
        print("3. Search Student")
        print("4. Update Student")
        print("5. Delete Student")
        print("6. Save Student")
        print("7. Exit")
        try:
            print("="*70)
            choice = int(input("Enter your choice(1-8):"))
            print("="*70)
            if choice == 1:
                add_students()
            elif choice == 2:
                display_students()
            elif choice == 3:
                search_students()
            elif choice == 4:
                update_students()
            elif choice == 5:
                delete_students()
            elif choice == 6:
                save_students()
            elif choice == 7:
                save_students()
                print("-"*70)
                print("Thank you for using Student Management System!")
                print("-"*70)
                break
            else:
                print("Invalid Input!!")
        except Exception as e:
            if choice == type(str):
            print(e)
        

system()
# Out:
# ✅ Students loaded successfully!
# ======================================================================
# STUDENT MANAGEMENT SYSTEM
# ======================================================================
#
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Save Student
# 7. Exit
# ======================================================================
# Enter your choice(1-8): a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 42
#      38         else:
#      39             print("Invalid Input!!")
# ---> 42 system()
#
# Cell In[22], line 18, in system()
#      15 print("7. Exit")
#      16 print("="*70)
# ---> 18 choice = int(input("Enter your choice(1-8):"))
#      19 print("="*70)
#      20 if choice == 1:
#
# ValueError: invalid literal for int() with base 10: 'a'
